# %% [markdown]
# # **The Cost Of Living Analytics In Lagos Nigeria.**
#
# *A Project by Joy Joseph*

# %% [markdown]
# ![](lagos.jpg)

# %% [markdown]
# ## **Introduction**
#
# When you pay bills, it would draw your attention to some hard reality that certain expenses hardly change instead it keeps increasing. Understanding this help us realize how important the cost of living is to surviving. The cost of living is regularly used to check how expensive it is to live in one place compared to other places. The cost of living is the required amount of money needed to solve basic needs such as, food, shelter, clothing, healthcare etc. at a point in time. There are basic expenses that are a part of the day to day life cycle, such as feeding, rent, healthcare, clothing, transportation, and childcare. All these expenses are recognized to be part of the cost of living. The Cost of living can differ from person to person due to some factors such as a person’s lifestyle and the size of one’s family. For example, transportation costs could differ based on the type of jobs and how you get to work. The bigger the size of your family, the more your expenses on things like feeding, healthcare and childcare.
#
# The cost of living in Nigeria differs significantly between states. The [cost of living index](https://www.investopedia.com/ask/answers/100214/how-cost-living-index-calculated.asp), is a relative indicator of consumer goods prices, including groceries, restaurants, transportation and utilities. Nigeria is ranked 122 Most Expensive Country to Live in by, the [Cost of Living Index for country 2022](https://www.numbeo.com/cost-of-living/rankings_by_country.jsp?title=2022&region=002).
#
# Looking at the current trend in the Economy, it is highly evident that the cost of living has continued to rise particularly in food related items. A lot of families are unable to provide a meal a day let alone three square meals. The Cost of living goes up mostly because of inflation. Nigeria’s annual inflation rate was at 15.60% in January of 2022, little changed from 15.63% in the previous month [National Bureau of Statistics](https://nigerianstat.gov.ng/elibrary/read/1241134). The widely used measure of inflation is the Consumer Price Index, it measures the average change in prices over time that consumers pay for a basket of goods and services. When there is inflation, fixed amount of money purchases less quantity of goods and services. The real value of money is significantly reduced. The impact is mostly felt by the low earners since an increase in the general prices of goods and services means they are able to buy just little or nothing with the money as compared to when they could.
#
# According to the [world population review](https://worldpopulationreview.com/countries/nigeria-population), Nigeria has 5 cities with populations of one million. Lagos is one of the largest, with a populace of about 17.5 million. Lagos, a city situated by the coastal region of Southwestern Nigeria, also Africa’s most populated city. Lagos is home to over 21 million people is considered to be the busiest city in Africa, a city filled with lots of unlimited opportunities, draws the younger populace across Nigeria and also different individuals from all over the world seeking for better opportunities.
#
# Lagos known to be the commercial hub and also the largest metropolitan area in Nigeria is considered to be a city that is regarded to be the economic powerhouse of Nigeria, it is also one of the most expensive states to live in. However, one interesting aspect of Lagos is that it accommodates both the wealthy, middle class and also the poor.
#
# So many people look for factors to decide if to move to a particular city or not. This is important as it is a benchmark in measuring how people survive. Knowing this helps to make sufficient preparations and aid decision making.  According to [NUMBEO](https://www.numbeo.com/cost-of-living/in/Lagos), the cost of living a Family of four estimated monthly cost are **₦809,210.49** without rent, a single person estimated monthly costs are **₦221,370.55** without rent in Lagos.
#
# Since the cost of living is insightful and also reflects a person’s well-being, having a view on how the cost of living affect people living in Lagos and realizing that the problems caused by the impacts of increased prices of goods and services is becoming unbearable to the citizens and the whole economy. It is critical to understanding what determines the cost of living and ways to minimize the effect.
#
# Some indicators will be used to measure the cost of living in Lagos. Indicators such as:
# •	Food
# •	Housing
# •	Transportation
# •	Energy
# •	Clothing
# •	Healthcare
# •	Childcare
#
#
#
#
# **Data Description**
#
# The dataset contains description and ways to which the cost of living can be analyzed, however, there are 7 important indicators to which the cost of living is measured. Such as: Food, Housing, Transportation, Energy, Clothing, Healthcare and Childcare. Some other features are also present in the data set.
#
# Data contains records of monthly Income for individuals spanning between 2020 and 2021.
#
# Total 17 numbers of attributes are provided in the Data. Attribute definition is:
#
# 1.	Timestamp: The record of time and date the respondent took the survey
#
# 2.	Age: The age range of Individuals
#
# 3.	Location: The local government area
#
# 4.	Gender: The Sexual category of individuals
#
# 5.	Marital Status: The marital state of individuals
#
# 6.	Monthly Income 2020: The Monthly Income for 2020
#
# 7.	Monthly Income 2021: The Monthly Income for 2021
#
# 8.	Accommodation: Monthly cost on accommodation
#
# 9.	Mobility : If the individual have a car or not
#
# 10.	Transportation: The monthly cost of transportation
#
# 11.	Feeding	: The monthly cost of food items
#
# 12.	Electricity: The monthly cost of electricity
#
# 13.	HealthCare: The monthly cost on drugs and improvement of health
#
# 14.	Health Issues: If the person has any chronic disease
#
# 15.	Name of Disease: Name of chronic disease
#
# 16.	Clothing: The monthly cost on clothing
#
# 17.	Childcare: The monthly cost on the care of children
#
#
# **Aims and Objectives**
#
# The aim of this project is to show an overview of the cost of living indicators across various locations within the scope of the project and also decomposing the cost of living into components such as Housing, Transportation, feeding, Electricity, Healthcare, Childcare and Clothing.
# To get real picture of the cost of living in Lagos, the study will cover only [Local Government Areas in Lagos](http://www.demographia.com/db-lagos.htm), such as, Agege, Ajeromi-Ifelodun, Alimosho, Apapa, Amuwo-Odofin, Badagry, Epe, Eti-Osa, Ibeju-Lekki, Ifako-Ijaiye, Ikeja, Ikorodu, Kosofe, Lagos Island, Lagos Mainland and Mushin.
#
# The project will follow some pattern. The Phases undertaken are:
#
# 1.	 Data Sourcing Phase
# 2.	 Data Cleaning & Investigation Phase
# 3.	Exploratory Data Analysis Phase
# 4.	Conclusion Phase
#
# 	Data Sourcing Phase: Here the source of the data will be highlighted.
#
# 	Data Cleaning & Investigation Phase: Here, we are after cleaning and removing any missing data.
#
# 	Exploratory Data Analysis Phase: The exploratory data analysis (EDA) will be performed, Bivariate and univariate Analysis to gain more insights.
#
# 	Conclusion Phase: Conclusion will be drawn.
#
#
#
#
# **Data Sourcing Phase**
#
# The data was obtained through an [online survey method](https://docs.google.com/forms/d/16siJhjnLM0Y1OQN9iJA3y1QOMp8O76Hlp0yrqgy9Noo/edit#responses), across [20 local government areas in Lagos state](https://grid3.gov.ng/dataset/lagos-local-government-administrative-boundaries/resources).

# %%
# importing required libraries 
import numpy as np
import pandas as pd 
import seaborn as sns; sns.set(style="ticks", color_codes=True)
import matplotlib.pyplot as plt

# %%
from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive

# Initializing a GoogleAuth Object
gauth = GoogleAuth()

# client_secrets.json file is verified
# and it automatically handles authentication
gauth.LocalWebserverAuth()

# GoogleDrive Instance is created using authenticated GoogleAuth instance
drive = GoogleDrive(gauth)

# Initialize GoogleDriveFile instance with file id
file_obj = drive.CreateFile({'id': '1FAN0LxrxrjSvGzWMKu7WvcEN3hDTjt9AEngTiXSAdmo'})
file_obj.GetContentFile('FILE_NAME.xls', 
		mimetype='application/vnd.openxmlformats-officedocument.spreadsheetml.sheet')

# loading and reading the datasets
# cl_df = cost of living in Lagos dataset
cl_df = pd.read_excel('FILE_NAME.xls')
# Out:
# Your browser has been opened to visit:
#
#     https://accounts.google.com/o/oauth2/auth?client_id=169997659677-98usthk6co1iqdfqhc8k737rst584dud.apps.googleusercontent.com&redirect_uri=http%3A%2F%2Flocalhost%3A8080%2F&scope=https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive&access_type=offline&response_type=code
#
# Authentication successful.

# %% [markdown]
# #### Data Cleaning & Investigation Phase
#
# In the Process, the Python Script and Local Environment was Authenticated with Google and the Google Form Data was accessed from Google Drive and used to enable the Google Drive API in Google Cloud Platform.

# %%
# an overview of the dataset
cl_df.head()
# Out:
#                 Timestamp  \
# 0 2022-02-28 16:20:45.001
# 1 2022-03-01 01:03:23.974
# 2 2022-03-01 01:09:27.356
# 3 2022-03-01 09:08:18.540
# 4 2022-03-01 09:14:53.098
#
#   Take this survey and stand a chance to win 2k recharge card.  \
# 0                                                Joy
# 1                                                MTN
# 2                                             Airtel
# 3                                                glo
# 4                                                MTN
#
#   How old are you Which area of Lagos do you reside  What is your gender  \
# 0         26 - 30                                NaN              Female
# 1         36 - 40                            Eti Osa                Male
# 2         31 - 35                           Alimosho              Female
# 3         26 - 30                       Amuwo-Odofin                Male
# 4         26 - 30                            Ikorodu              Female
#
# ...

# %%
# checking the dimensions of the data frame
print("The Shape is: ", cl_df.shape)
# Out:
# The Shape is:  (317, 18)

# %%
# checking for the data types
cl_df.dtypes
# Out:
# Timestamp                                                       datetime64[ns]
# Take this survey and stand a chance to win 2k recharge card.            object
# How old are you                                                         object
# Which area of Lagos do you reside                                       object
# What is your gender                                                     object
# What is your Marital Status                                             object
# What is your Monthly Income as at 31-12-2020                            object
# What is your Monthly Income for 31-12-2021                              object
# What is your monthly cost  on  Accommodation                            object
# Do you have a car                                                       object
# How much do you spend on Transportation monthly                         object
# How much do you spend on Feeding monthly                                object
# ...

# %%
# a view of all the column
cl_df.columns
# Out:
# Index(['Timestamp',
#        'Take this survey and stand a chance to win 2k recharge card.',
#        'How old are you', 'Which area of Lagos do you reside ',
#        'What is your gender', 'What is your Marital Status',
#        'What is your Monthly Income as at 31-12-2020',
#        'What is your Monthly Income for 31-12-2021',
#        'What is your monthly cost  on  Accommodation', 'Do you have a car',
#        'How much do you spend on Transportation monthly',
#        'How much do you spend on Feeding monthly',
#        'How much do you spend on Electricity monthly',
#        'How much do you spend on HealthCare monthly',
#        'Do you have any underlining Health Issues', 'If yes what is it?',
#        'How much do you spend on Clothing monthly',
#        'How much do you spend on Childcare monthly'],
#       dtype='object')

# %%
# renaming column
cl_df.columns = ['Timestamp','Recharge_card','Age', 'Location','Gender', 'Marital_Status','M_Income_2020',
       'M_Income_2021','Accommodation', 'Mobility','Transportation','Feeding','Electricity',
       'HealthCare','Health_Issues', 'Name_of_Disease','Clothing','Childcare']

# %%
# an overview of the dataset after renaming the columns
cl_df.head()
# Out:
#                 Timestamp Recharge_card      Age      Location  Gender  \
# 0 2022-02-28 16:20:45.001           Joy  26 - 30           NaN  Female
# 1 2022-03-01 01:03:23.974           MTN  36 - 40       Eti Osa    Male
# 2 2022-03-01 01:09:27.356        Airtel  31 - 35      Alimosho  Female
# 3 2022-03-01 09:08:18.540           glo  26 - 30  Amuwo-Odofin    Male
# 4 2022-03-01 09:14:53.098           MTN  26 - 30       Ikorodu  Female
#
#   Marital_Status      M_Income_2020      M_Income_2021    Accommodation  \
# 0         Single  100,000 - 150,000                NaN   5,000 - 20,000
# 1         Single  300,000 - 500,000  300,000 - 500,000    95,000  above
# 2        Married   60,000 - 100,000  100,000 - 150,000   5,000 - 10,000
# 3         Single   60,000 - 100,000   60,000 - 100,000  15,000 - 40,000
# 4         Single    20,000 - 50,000   60,000 - 100,000  45,000 - 60,000
#
#   Mobility   Transportation           Feeding      Electricity  \
# ...

# %%
# dropping unimportant columns
cl_df = cl_df.drop(columns=['Recharge_card', 'Mobility', 'Name_of_Disease'])

cl_df.head()
# Out:
#                 Timestamp      Age      Location  Gender Marital_Status  \
# 0 2022-02-28 16:20:45.001  26 - 30           NaN  Female         Single
# 1 2022-03-01 01:03:23.974  36 - 40       Eti Osa    Male         Single
# 2 2022-03-01 01:09:27.356  31 - 35      Alimosho  Female        Married
# 3 2022-03-01 09:08:18.540  26 - 30  Amuwo-Odofin    Male         Single
# 4 2022-03-01 09:14:53.098  26 - 30       Ikorodu  Female         Single
#
#        M_Income_2020      M_Income_2021    Accommodation   Transportation  \
# 0  100,000 - 150,000                NaN   5,000 - 20,000   5,000 - 20,000
# 1  300,000 - 500,000  300,000 - 500,000    95,000  above  45,000 - 60,000
# 2   60,000 - 100,000  100,000 - 150,000   5,000 - 10,000   5,000 - 10,000
# 3   60,000 - 100,000   60,000 - 100,000  15,000 - 40,000  15,000 - 40,000
# 4    20,000 - 50,000   60,000 - 100,000  45,000 - 60,000  15,000 - 40,000
#
#             Feeding      Electricity       HealthCare Health_Issues  \
# ...

# %% [markdown]
# Inference
#
# The above operation shows that some Columns were dropped. The reason for dropping this columns is because they are not relevant in our analysis.

# %%
# summary statistics of the dataset
cl_df.describe()
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_19508\2485320985.py:2: FutureWarning: Treating datetime data as categorical rather than numeric in `.describe` is deprecated and will be removed in a future version of pandas. Specify `datetime_is_numeric=True` to silence this warning and adopt the future behavior now.
#   cl_df.describe()
#                          Timestamp      Age Location Gender Marital_Status  \
# count                          317      317      316    317            317
# unique                         317        9       20      2              4
# top     2022-02-28 16:20:45.001000  31 - 35    Ikeja   Male         Single
# freq                             1       89       35    186            172
# first   2022-02-28 16:20:45.001000      NaN      NaN    NaN            NaN
# last    2022-03-08 16:10:54.663000      NaN      NaN    NaN            NaN
#
#           M_Income_2020     M_Income_2021    Accommodation   Transportation  \
# ...

# %%
# checking for missing data
cl_df.isnull().sum()
# Out:
# Timestamp          0
# Age                0
# Location           1
# Gender             0
# Marital_Status     0
# M_Income_2020      0
# M_Income_2021      1
# Accommodation      0
# Transportation     0
# Feeding            0
# Electricity        0
# HealthCare         0
# Health_Issues      8
# Clothing           2
# Childcare         21
# dtype: int64

# %%
# visualizing missing data
import missingno as msno
msno.bar(cl_df)
# Out:
# <AxesSubplot:>

# %%
# Printing the total number of missing values
print(cl_df.isnull().sum().sum())
# Out:
# 33

# %% [markdown]
# Inference
#
# There are 33 missing values in the datasets. colum names with missing values are; Location, Monthly_Income_2021, Health_Issues, Clothing, and Childcare. Hence, cleaning operation will be performed.

# %% [markdown]
# *Treating Missing Values*

# %%
# dropping the missing value from the Location column
cl_df.dropna(subset=['Location'], inplace=True)

# checking the Location column ater dropping missing data
print(cl_df['Location'].isnull().sum())
# Out:
# 0

# %%
# dropping the missing value from the Monthly Income in 2021 column
cl_df.dropna(subset=['M_Income_2021'], inplace=True)

# checking the Monthly Income 2021 column ater dropping missing data
print(cl_df['M_Income_2021'].isnull().sum())
# Out:
# 0

# %%
# replacing the missing value with zero in the Health Issues column
cl_df.Health_Issues.fillna(0, inplace=True)

# checking the Health Issues column ater replacing missing data with zero
print(cl_df['Health_Issues'].isnull().sum())
# Out:
# 0

# %%
# dropping the missing value from the Clothing column
cl_df.dropna(subset=['Clothing'], inplace=True)

# checking the Clothing column ater dropping missing data
print(cl_df['Clothing'].isnull().sum())
# Out:
# 0

# %%
# replacing the missing value with zero in the Childcare column
cl_df.Childcare.fillna(0, inplace=True)

# checking the Health Issues column ater replacing  missing data with zero
print(cl_df['Childcare'].isnull().sum())
# Out:
# 0

# %%
# visualizing dataset after impututing with Zero
import missingno as msno
msno.bar(cl_df)
# Out:
# <AxesSubplot:>

# %% [markdown]
# Inference
#
# After Cleaning we see that there are no more some missing values in the datasets.

# %% [markdown]
# #### Exploratory Data Analysis Phase
#
# *Univariate Analysis*

# %%
# finding value counts fot the Location column
cl_df.Location.value_counts()
# Out:
# Ikeja               35
# Lagos Island        33
# Surulere            31
# Eti Osa             30
# Ikorodu             25
# Lagos Mainland      23
# Kosofe              19
# Ibeju-Lekki         15
# Ifako-Ijaiye        14
# Amuwo-Odofin        14
# Shomolu             13
# Alimosho            11
# Agege               10
# Oshodi-Isolo        10
# Epe                  8
# Mushin               7
# Badagry              7
# Apapa                5
# Ojo                  4
# Ajeromi-Ifelodun     1
# Name: Location, dtype: int64

# %% [markdown]
# Inference
#
# From the above, we see that from the 20 local government areas in lagos, the respondents living in Ikeja is more, followed by Lagos Island, Surulere, Eti-osa and Ikorodu than the rest.

# %%
# finding value counts fot the Age column
cl_df.Age.value_counts()
# Out:
# 31 - 35     89
# 26 - 30     67
# 36 - 40     53
# 20 - 25     43
# 41 - 45     23
# 46 - 50     19
# 56 - 60     10
# 51 - 55      7
# 61 above     4
# Name: Age, dtype: int64

# %%
# checking for the count for Age
plt.title('Age Count')
sns.countplot(cl_df['Age'])
plt.show()
# Out:
# c:\Users\USER\Desktop\Capestone Project1\Sales_Forecasting_for_Walmart\capstone_env\lib\site-packages\seaborn\_decorators.py:36: FutureWarning:
#
# Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.

# %% [markdown]
# Inference
#
# From the graph above, we see that age 31 - 35 is more followed by age 26 - 30 and age 36 - 40, with age 61 above being the least.

# %%
# finding value counts fot the Marital Status column
cl_df.Marital_Status.value_counts()
# Out:
# Single      170
# Married     124
# Widowed      14
# Divorced      7
# Name: Marital_Status, dtype: int64

# %%
# checking for the count for Marital Status
plt.title('Marital Status Count')
sns.countplot(cl_df['Marital_Status'])
plt.show()
# Out:
# c:\Users\USER\Desktop\Capestone Project1\Sales_Forecasting_for_Walmart\capstone_env\lib\site-packages\seaborn\_decorators.py:36: FutureWarning:
#
# Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.

# %% [markdown]
# Inference
#
# From the graph above, we see that we have more of Single and Married, while  Widowed and Divorced is low.

# %%
# finding value counts fot the Gender column
cl_df.Gender.value_counts()
# Out:
# Male      185
# Female    130
# Name: Gender, dtype: int64

# %%
# checking the distribution for Gender
plt.figure(figsize=(6,6))
plt.pie(x=[185,  130], labels=['Male','Female'], autopct='%1.0f%%', pctdistance=0.5,labeldistance=0.7,colors=['b','r'])
plt.title('Distribution of Gender')
# Out:
# Text(0.5, 1.0, 'Distribution of Gender')

# %% [markdown]
# Inference
#
# From the graph above, we see that the distribution of Gender is 59% male and 41% female.

# %%
# finding value counts for Monthly Accomdation 
cl_df.Accommodation.value_counts()
# Out:
# 15,000 - 40,000    112
# 95,000  above       64
# 5,000 - 10,000      50
# 45,000 - 60,000     39
# 0 - 5,000           35
# 65,000 - 90,000      8
# 65,000 - 80,000      7
# Name: Accommodation, dtype: int64

# %%
plt.figure(figsize=(12,5)) # plot size

# checking for the count and graphing the cost of Monthly accommodation
plt.title('Monthly Cost on Accommodation')
sns.countplot(cl_df['Accommodation'])
plt.show()
# Out:
# c:\Users\USER\Desktop\Capestone Project1\Sales_Forecasting_for_Walmart\capstone_env\lib\site-packages\seaborn\_decorators.py:36: FutureWarning:
#
# Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.

# %% [markdown]
# Inference
#
# From the graph above, we can see that the amount of money spent on accommodation(Housing) is more between 15,000 - 40,000, and 95,000 above monthly range than the rest. This could imply that according to the response, the Monthly cost of Accommodation can be said to be high.

# %%
# finding value counts for Monthly Transportation
cl_df.Transportation.value_counts()
# Out:
# 15,000 - 40,000    162
# 5,000 - 10,000      74
# 0 - 5,000           32
# 45,000 - 60,000     31
# 65,000 above        16
# Name: Transportation, dtype: int64

# %%
plt.figure(figsize=(12,5)) # plot size

# checking for the count and graphing the cost of Monthly Transportation
plt.title('Monthly Cost on Transportation')
sns.countplot(cl_df['Transportation'])
plt.show()
# Out:
# c:\Users\USER\Desktop\Capestone Project1\Sales_Forecasting_for_Walmart\capstone_env\lib\site-packages\seaborn\_decorators.py:36: FutureWarning:
#
# Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.

# %% [markdown]
# Inference
#
# From the graph above, we can see that the amount of money spent on Transportation is more between 15,000 - 40,000, and 5,000 - 10,000 monthly range than the rest.

# %%
# finding value counts for Monthly Feeding 
cl_df.Feeding.value_counts()
# Out:
# 15,000 - 40,000     145
# 45,000 - 60,000      71
# 65,000 - 80,000      32
# 5,000 - 10,000       23
# 100,000 above        22
# 85,000 - 100,000     21
# 0 - 5,000             1
# Name: Feeding, dtype: int64

# %%
plt.figure(figsize=(12,5)) # plot size

# checking for the count and graphing the cost of Monthly Feeding
plt.title('Monthly Cost on Feeding')
sns.countplot(cl_df['Feeding'])
plt.show()
# Out:
# c:\Users\USER\Desktop\Capestone Project1\Sales_Forecasting_for_Walmart\capstone_env\lib\site-packages\seaborn\_decorators.py:36: FutureWarning:
#
# Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.

# %% [markdown]
# Inference
#
# From the graph above, we can see that the amount of money spent on Feeding is more between 15,000 - 40,000, 45,000 - 60,000, and 65,000 - 80,000 monthly range than the rest.

# %%
# finding value counts for Monthly Electricity
cl_df.Electricity.value_counts()
# Out:
# 5,000 - 10,000      115
# 0 - 5,000            97
# 15,000 - 40,000      80
# 45,000 - 60,000      13
# 65,000 - 80,000       4
# 85,000 - 100,000      3
# 100,000 above         3
# Name: Electricity, dtype: int64

# %%
plt.figure(figsize=(12,5)) # plot size

# checking for the count and graphing the cost of Electricity
plt.title('Monthly Cost on Electricity')
sns.countplot(cl_df['Electricity'])
plt.show()
# Out:
# c:\Users\USER\Desktop\Capestone Project1\Sales_Forecasting_for_Walmart\capstone_env\lib\site-packages\seaborn\_decorators.py:36: FutureWarning:
#
# Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.

# %% [markdown]
# Inference
#
# From the graph above, we can see that the amount of money spent on Electricity is more between 5,000 - 10,000, 0 - 5,000, and 15,000 - 40,000 monthly range than the rest.

# %%
# finding value counts for Monthly HealthCare
cl_df.HealthCare.value_counts()
# Out:
# 0 - 5,000          132
# 5,000 - 10,000     108
# 15,000 - 40,000     57
# 45,000 - 65,000     12
# 90,000 above         3
# 70,000 - 85,000      3
# Name: HealthCare, dtype: int64

# %%
plt.figure(figsize=(12,5)) # plot size

# checking for the count and graphing the cost of HealthCare
plt.title('Monthly Cost on HealthCare')
sns.countplot(cl_df['HealthCare'])
plt.show()
# Out:
# c:\Users\USER\Desktop\Capestone Project1\Sales_Forecasting_for_Walmart\capstone_env\lib\site-packages\seaborn\_decorators.py:36: FutureWarning:
#
# Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.

# %% [markdown]
# Inference
#
# From the graph above, we can see that the amount of money spent on HealthCare is more between 0 - 5,000, 5,000 - 10,000, and 15,000 - 40,000 monthly range than the rest.

# %%
# finding value counts for Monthly Clothing
cl_df.Clothing.value_counts()
# Out:
# 15,000 - 40,000    114
# 5,000 - 10,000      93
# 0 - 5,000           65
# 45,000 - 65,000     25
# 70,000 - 95,000     10
# 100 above            8
# Name: Clothing, dtype: int64

# %%
plt.figure(figsize=(12,5)) # plot size

# checking for the count and graphing the cost of Clothing
plt.title('Monthly Cost on Clothing')
sns.countplot(cl_df['Clothing'])
plt.show()
# Out:
# c:\Users\USER\Desktop\Capestone Project1\Sales_Forecasting_for_Walmart\capstone_env\lib\site-packages\seaborn\_decorators.py:36: FutureWarning:
#
# Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.

# %% [markdown]
# Inference
#
# From the graph above, we can see that the amount of money spent on Clothing is more between 15,000 - 40,000, 5,000 - 10,000, and 0 - 5,000 monthly range than the rest.

# %%
# finding value counts for Monthly Childcare
cl_df.Childcare.value_counts()
# Out:
# 0 - 5,000           143
# 15,000 - 40,000      63
# 5,000 - 10,000       57
# 0                    19
# 45,000 - 80,000      19
# 100,000  above        9
# 85,000 - 100,000      5
# Name: Childcare, dtype: int64

# %%
plt.figure(figsize=(12,5)) # plot size

# checking for the count and graphing the cost of Childcare
plt.title('Monthly Cost on Childcare')
sns.countplot(cl_df['Childcare'])
plt.show()
# Out:
# c:\Users\USER\Desktop\Capestone Project1\Sales_Forecasting_for_Walmart\capstone_env\lib\site-packages\seaborn\_decorators.py:36: FutureWarning:
#
# Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.

# %% [markdown]
# Inference
#
# From the graph above, we can see that the amount of money spent on Childcare is more between 0 - 5,000, 5,000 - 10,000, and 15,000 - 40,000 monthly range than the rest.

# %%
# checking for the count for Health Issues
plt.title('Health Issues Count')
sns.countplot(cl_df['Health_Issues'])
plt.show()
# Out:
# c:\Users\USER\Desktop\Capestone Project1\Sales_Forecasting_for_Walmart\capstone_env\lib\site-packages\seaborn\_decorators.py:36: FutureWarning:
#
# Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.

# %% [markdown]
# Inference
#
# From the graph above, we see that we that people without health issues are more than people with it.

# %%
# checking for the unique values of M_Income_2020
cl_df['M_Income_2020'].unique()
# Out:
# array(['60,000 - 100,000', '20,000 - 50,000', '100,000 - 150,000',
#        '500,000 above', '300,000 - 500,000', '150,000 - 200,000',
#        '200,000 - 290,000'], dtype=object)

# %%
# checking for the unique values of M_Income_2021
cl_df['M_Income_2021'].unique()
# Out:
# array(['100,000 - 150,000', '60,000 - 100,000', '500,000 above',
#        '300,000 - 500,000', '150,000 - 200,000', '200,000 - 290,000',
#        '20,000 - 50,000'], dtype=object)

# %%
from sklearn import preprocessing

# transforming categorical data to numerical values
# transgorming the income values to numerical values
le = preprocessing.LabelEncoder()

def transform_data(df,col):
    df[col] = le.fit_transform(df[col])
    return df

cl_df = transform_data(cl_df,'M_Income_2020')
cl_df = transform_data(cl_df,'M_Income_2021')

# combing two lists into list of tuples
list(
    zip(
        cl_df['M_Income_2020'].unique(), 
        le.inverse_transform(cl_df['M_Income_2020'].unique()
        )
    )
)
# Out:
# [(6, '60,000 - 100,000'),
#  (2, '20,000 - 50,000'),
#  (0, '100,000 - 150,000'),
#  (5, '500,000 above'),
#  (4, '300,000 - 500,000'),
#  (1, '150,000 - 200,000'),
#  (3, '200,000 - 290,000')]

# %% [markdown]
# Inference
#
# We see that we have transfromed the categorical values to numerical values. Where 6 represents earners within the monthly income of ₦60,000 - ₦100,000, 2 represents earners within the monthly income of ₦20,000 - ₦50,000, 0  represents earners within the monthly income of ₦100,000 - ₦150,000, 5 represents earners within the monthly income of ₦500,000 above, 4 represents earners within the monthly income of ₦300,000 - ₦500,000, 1 represents earners within the monthly income of ₦150,000 - ₦200,000, and 3 represents earners within the monthly income of ₦200,000 - ₦290,000.

# %%
# Group by LGA and determine the mean values
df = cl_df.groupby('Location')['M_Income_2020','M_Income_2021'].mean().reset_index()
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_19508\2486126117.py:2: FutureWarning:
#
# Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.

# %%
# groupby location and checking the aggregates Monthly Income for 2020
cl_df.groupby('Location').agg({'M_Income_2020':'mean', 'Timestamp':'count'}).reset_index()
# Out:
#             Location  M_Income_2020  Timestamp
# 0              Agege       2.100000         10
# 1   Ajeromi-Ifelodun       2.000000          1
# 2           Alimosho       3.818182         11
# 3       Amuwo-Odofin       3.857143         14
# 4              Apapa       6.000000          5
# 5            Badagry       3.285714          7
# 6                Epe       2.125000          8
# 7            Eti Osa       3.700000         30
# 8        Ibeju-Lekki       2.533333         15
# 9       Ifako-Ijaiye       2.642857         14
# 10             Ikeja       2.371429         35
# 11           Ikorodu       3.000000         25
# 12            Kosofe       1.894737         19
# 13      Lagos Island       3.000000         33
# 14    Lagos Mainland       2.173913         23
# 15            Mushin       3.571429          7
# 16               Ojo       1.750000          4
# 17      Oshodi-Isolo       2.200000         10
# 18           Shomolu       2.692308         13
# ...

# %% [markdown]
# Inference
#
# We see that we have 20 Local government areas in lagos, we can also see the aggregated average monthly income for 2020 and the number of  respondent (from the Timestamp column) staying in a particular local government area.
#
# From this we can conclude that, according to the response, areas like Alimosho, Amuwo-Odofin, Eti-Osa, Mushin, Lagos Island, Badagry, and Ikorodu earn averagely between ₦200,000 - ₦290,000. Areas like Ifako-Ijaiye, Ibeju-Lekki, Surulere, Shomolu, Agege, Epe, Ajeromi-Ifelodun, Lagos Mainland, and Oshodi-Isolo earn averagely between ₦20,000 - ₦50,000. Areas like Kosofe, and  Ojo, earn averagely between ₦150,000 - ₦200,000. Areas like Apapa, earn averagely between ₦60,000 - ₦100,000.

# %%
# groupby location and checking the aggregates for Monthly Income for 2021, and Timestamp
cl_df.groupby('Location').agg({'M_Income_2021':'mean', 'Timestamp':'count'}).reset_index()
# Out:
#             Location  M_Income_2021  Timestamp
# 0              Agege       2.100000         10
# 1   Ajeromi-Ifelodun       2.000000          1
# 2           Alimosho       3.454545         11
# 3       Amuwo-Odofin       3.428571         14
# 4              Apapa       6.000000          5
# 5            Badagry       3.285714          7
# 6                Epe       1.375000          8
# 7            Eti Osa       3.166667         30
# 8        Ibeju-Lekki       2.466667         15
# 9       Ifako-Ijaiye       2.928571         14
# 10             Ikeja       2.628571         35
# 11           Ikorodu       3.400000         25
# 12            Kosofe       2.263158         19
# 13      Lagos Island       3.060606         33
# 14    Lagos Mainland       2.000000         23
# 15            Mushin       3.000000          7
# 16               Ojo       2.750000          4
# 17      Oshodi-Isolo       2.900000         10
# 18           Shomolu       3.461538         13
# ...

# %% [markdown]
# Inference
#
# We see that we have 20 Local government areas in lagos, we can also see the aggregated average monthly income for 2021 and the number of respondent(from the Timestamp column) staying in a particular local government area of Lagos.
#
# From this we can conclude that, according to the response, areas like Alimosho, Amuwo-Odofin, Eti-Osa, Mushin, Lagos Island, Badagry, and Ikorodu earn averagely between ₦200,000 - ₦290,000. Areas like Ifako-Ijaiye, Ibeju-Lekki, Surulere, Shomolu, Agege, Ajeromi-Ifelodun, Lagos Mainland, Ojo and Oshodi-Isolo earn averagely between ₦20,000 - ₦50,000. Areas like Kosofe, and Epe earn averagely between ₦150,000 - ₦200,000. Areas like Apapa, earn averagely between ₦60,000 - ₦100,000.

# %%
# Clean-up the LGA descriptions

df['Location'] = \
    df['Location'].replace('Amuwo-Odofin','Amuwo Odofin') \
    .replace('Ibeju-Lekki','Ibeju Lekki') \
    .replace('Ifako-Ijaiye','Ifako/Ijaye') \
    #.str.replace('-','/') \

# %%
import geopandas as gpd
import geoplot
import geoplot.crs as gcrs

# reading the Lagos Local Government Administrative Boundaries dataset
lga_data = gpd.read_file("Data\local-government-administrative-boundaries.geojson") 

lga_data.plot()
# Out:
# <AxesSubplot:>

# %%
geoplot.polyplot(lga_data, projection=gcrs.AlbersEqualArea(), edgecolor='darkgrey', facecolor='lightgrey', linewidth=.3,
    figsize=(12, 8))
# Out:
# <GeoAxesSubplot:>

# %%
geoplot.polyplot(lga_data, figsize=(12, 8))
# Out:
# C:\Users\USER\Desktop\Capestone Project1\The_Cost_of_Living_in_Lagos\envs\lib\site-packages\geoplot\geoplot.py:885: ShapelyDeprecationWarning: Iteration over multi-part geometries is deprecated and will be removed in Shapely 2.0. Use the `geoms` property to access the constituent parts of a multi-part geometry.
#   for subgeom in geom:
# <AxesSubplot:>

# %%
# Join the map data to survey data

fullData = lga_data.merge(df, left_on=['lga_name'], right_on=['Location'])
fullData
# Out:
#                      id state_code     source lga_code        lga_name  \
# 0    u_boundary_lgas.64         LA  eHA_Polio    25011           Ikeja
# 1    u_boundary_lgas.69         LA  eHA_Polio    25014          Mushin
# 2   u_boundary_lgas.339         LA  eHA_Polio    25001           Agege
# 3   u_boundary_lgas.401         LA  eHA_Polio    25005           Apapa
# 4   u_boundary_lgas.411         LA  eHA_Polio    25003        Alimosho
# 5   u_boundary_lgas.412         LA  eHA_Polio    25019  Lagos Mainland
# 6   u_boundary_lgas.429         LA  eHA_Polio    25017         Shomolu
# 7   u_boundary_lgas.441         LA  eHA_Polio    25013          Kosofe
# 8   u_boundary_lgas.477         LA  eHA_Polio    25018        Surulere
# 9   u_boundary_lgas.543         LA  eHA_Polio    25020    Lagos Island
# 10  u_boundary_lgas.673         LA  eHA_Polio    25012         Ikorodu
# 11  u_boundary_lgas.678         LA  eHA_Polio    25007             Epe
# ...

# %%
# Initialize the figure
import matplotlib.pyplot as plt
fig, ax = plt.subplots(1, 1, figsize=(16, 12))

# Set up the color sheme:
import mapclassify as mc
scheme = mc.Quantiles(fullData['M_Income_2020'], k=7)

# Map
geoplot.choropleth(fullData, 
    hue='M_Income_2020', 
    linewidth=.1,
    scheme=scheme, cmap='inferno_r',
    legend=True,
    edgecolor='black',
    ax=ax
)

ax.set_title('Monthly Income Across Lagos Local Admin Areas', fontsize=13);

# %% [markdown]
# Inference
#
# The high/deep contrast colour represents the local government areas with high income earners, while the low/light contrast color represents the local government areas with low earners.

# %% [markdown]
# ### *Did monthly income change?*

# %%
#Comparing The Monthly Income For 2020 and 2021 to see if there is any change
df.plot(kind='barh')
# Out:
# <AxesSubplot:>

# %% [markdown]
# Inference
#
# From the plot above, we can see that Monthly income though changed slightly but still remains the same for 2020 and 2021 across areas in Lagos state.

# %% [markdown]
# *Bivariate Analysis*

# %%
import plotly.express as px

# %% [markdown]
# Inference
#
# Areas in Lagos State will be represented by three categories. The Higher Category ranging from 65,000 - 80,000, 65,000 - 90,000, and 95,000 above.  The medium Category ranging from 15,000 - 40,000 and 45,000 - 60,000, and the lower Category ranging from 0 - 5,000, and  5,000 - 10,000.
#
# Areas in Lagos with Higher monthly cost of Accommodation are; Lagos Island, Ikeja, Eti Osa, Surulere, Lagos Mainland, Ifako-ijaiye, and Mushin.
#
# Areas in Lagos state with Medium monthly cost of Accommodation are; Lagos Island, Lagos Mainland, Ibeju lekki, Apapa, Badagry, Ojo, and Epe.
#
# While Areas in Lagos state with low monthly cost of Accommodation are; Ikorodu, Badagry, Amuuwo-odofin, Ifako-ijaiye, Mushin, Ajeromi-ifelodun and  Ikeja.

# %%
# plotting a scatter graph that shows the relationship between Monthly Transportation 
# and Monthly Income using year 2021.
px.scatter(cl_df, y="M_Income_2021", x="Transportation", color="Location", size_max=60, height=500,)

# %% [markdown]
# Inference
#
# Areas in Lagos State will be represented by three categories. The Higger Category ranging from 45,000 - 60,000, and 65,000 above.  The medium Category ranging from 15,000 - 40,000 and the lower Category ranging from 0 - 5,000, and  5,000 - 10,000.
#
# Areas in Lagos with Higher monthly cost of Transportation are; Lagos Island, Ikeja, Eti Osa, Ibeju lekki, Lagos Mainland, and Epe
#
# Areas in Lagos state with Medium monthly cost of Transportation are; Lagos Island, Lagos Mainland, Apapa, Badagry, Ojo, and Epe.
#
# While Areas in Lagos state with low monthly cost of Transportation are; Ikorodu, Badagry, ibeju lekki, Ifako-ijaiye, Mushin, Eti Osa and Ajeromi-ifelodun.

# %%
# plotting a scatter graph that shows the relationship between Monthly Feeding	 
# and Monthly Income using year 2021.
px.scatter(cl_df, y="M_Income_2021", x="Feeding", color="Location", size_max=60, height=500,)

# %% [markdown]
# Inference
#
# Areas in Lagos State will be represented by three categories. The Higher Category ranging from 85,000 - 100,000, and 100,000 above.  The medium Category ranging from 15,000 - 40,000, 45,000 - 60,000 and  65,000 - 80,000, and the lower Category ranging from 0 - 5,000, and  5,000 - 10,000.
#
# Areas in Lagos with Higher monthly cost of Feeding are; Lagos Island, Ikeja, Eti Osa, Ibeju lekki, Lagos Mainland, and Surulere
#
# Areas in Lagos state with Medium monthly cost of Feeding are; Apapa, Badagry, Apapa, Ojo, Lagos Island, Lagos Mainland, and Ajeromi-ifelodun.
#
# While Areas in Lagos state with low monthly cost of Feeding are; Epe, Alomosho, Ikorodu, Badagry,  Ifako-ijaiye, lagos mainland and Epe.

# %%
# plotting a scatter graph that shows the relationship between Monthly Electricity	 
# and Monthly Income using year 2021.
px.scatter(cl_df, y="M_Income_2021", x="Electricity", color="Location", size_max=60, height=500,)

# %% [markdown]
# Inference
#
# Areas in Lagos State will be represented by three categories. The Higher Category ranging from 65,000 - 80,000, 85,000 - 100,000 and 100,000 above.  The medium Category ranging from 15,000 - 40,000, 45,000 - 60,000 and  65,000 - 80,000, and the lower Category ranging from 0 - 5,000, and  5,000 - 10,000.
#
# Areas in Lagos with Higher monthly cost of Electricity are; Lagos Island, Eti Osa, Ikeja, and Surulere
#
# Areas in Lagos state with Medium monthly cost of Electricity are; Apapa, Lagos Island, Lagos Mainland, and Epe.
#
# While Areas in Lagos state with low monthly cost of Electricity are; Badagry, Epe, Alomosho, Ikorodu, Ojo, Ibeju lekki, Ajeromi, Shomolu, lagos mainland and Epe.

# %%
# plotting a scatter graph that shows the relationship between Monthly HealthCare		 
# and Monthly Income using year 2021.
px.scatter(cl_df, y="M_Income_2021", x="HealthCare", color="Location", size_max=60, height=500,)

# %% [markdown]
# Inference
#
# Areas in Lagos State will be represented by three categories. The Higer Category ranging from  70,000 - 85,000 and 90,000 above.  The medium Category ranging from 15,000 - 40,000, and 45,000 - 65,000, the lower Category ranging from 0 - 5,000, and  5,000 - 10,000.
#
# Areas in Lagos with Higher monthly cost of HealthCare are; Lagos Island, Eti Osa, Ikeja, shomolu, and Surulere
#
# Areas in lagos state with Medium monthly cost of HealthCare are; Agege, Lagos Island, Lagos Mainland, Alimosho, Surulere and Eti Osa.
#
# While Areas in lagos state with with low monthly cost of HealthCare are; Badagry, Epe, Ikorodu, Ojo, Ibeju lekki, Ajeromi, Shomolu, lagos mainland, Apapa and Epe.

# %%
# plotting a scatter graph that shows the relationship between Monthly Clothing		 
# and Monthly Income using year 2021.
px.scatter(cl_df, y="M_Income_2021", x="Clothing", color="Location", size_max=60, height=500,)

# %% [markdown]
# Inference
#
# Areas in Lagos State will be represented by three categories. The Higher Category ranging from  70,000 - 95,000 and 100,000 above.  The medium Category ranging from 15,000 - 40,000, and 45,000 - 65,000, the lower Category ranging from 0 - 5,000, and  5,000 - 10,000.
#
# Areas in Lagos with Higher monthly cost of Clothing are; Lagos Island, Surulere, Eti Osa, Ibeju-lekki, Ifako-ijaiye, and Lagos Mainland
#
# Areas in Lagos state with Medium monthly cost of Clothing are; Agege, Lagos Island, Lagos Mainland, and Oshodi-Isolo.
#
# While Areas in Lagos state with low monthly cost of Clothing are; Badagry, Epe, Ikorodu,  Ibeju lekki, Ajeromi, Shomolu, lagos mainland, Apapa and Eti-Osa.

# %%
# plotting a scatter graph that shows the relationship between Monthly Childcare	 
# and Monthly Income using year 2021.
px.scatter(cl_df, y="M_Income_2021", x="Childcare", color="Location", size_max=60, height=500,)

# %% [markdown]
# Inference
#
# Areas in Lagos State will be represented by three categories. The Higher Category ranging from  85,000 - 100,000 and 100,000 above.  The medium Category ranging from 15,000 - 40,000, and 45,000 - 80,000, the lower Category ranging from 0 - 5,000, and  5,000 - 10,000.
#
# Areas in Lagos with Higher monthly cost of Childcare are; Lagos Island, Lagos Mainland, Surulere, Eti Osa, Ibeju-lekki,
#
# Areas in Lagos state with Medium monthly cost of Childcare are; Surulere, Lagos Island, Lagos Mainland, Mushin, and Ifako-ijaiye.
#
# While Areas in Lagos state with with low monthly cost of Childcare are; Badagry, Epe, Ibeju lekki, Ajeromi, Shomolu, lagos mainland, Apapa and Eti-Osa.

# %%
# Plotting a scatter matrix for Accommodation, Transportation and feeding across areas in Lagos state
fig = px.scatter_matrix(cl_df,
    dimensions=["Accommodation", "Transportation", "Feeding"],
    color="Location", symbol="Location",
    title="The Cost of Living in Lagos",)
    
fig.update_traces(diagonal_visible=False)

fig.show()

# %% [markdown]
# Inference
#
# From the above plot, Comparing Accommodation, Transportation, and Feeding indicators shows that the monthly cost of Feeding is higher than the cost of Accommodation and Transportation across various Local Government areas of lagos state. This means that earners spend a higher fraction of their Monthly income on Feeding. Also, the monthly cost of Accommodation is higher compared to the monthly cost of Transportation.

# %%
# Plotting a scatter matrix for Electricity, HealthCare, Clothing, and  "Childcare across areas in Lagos state

fig = px.scatter_matrix(cl_df,
    dimensions=["Electricity", "HealthCare", "Clothing", "Childcare"],
    color="Location", symbol="Location",
    title="The Cost of Living in Lagos",)
    
fig.update_traces(diagonal_visible=False)

fig.show()
# Out:
# <div>                            <div id="2d1cd1c9-b22e-4186-8c70-e65d77cc0a16" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("2d1cd1c9-b22e-4186-8c70-e65d77cc0a16")) {                    Plotly.newPlot(                        "2d1cd1c9-b22e-4186-8c70-e65d77cc0a16",                        [{"dimensions":[{"axis":{"matches":true},"label":"Electricity","values":["5,000 - 10,000","5,000 - 10,000","5,000 - 10,000","5,000 - 10,000","5,000 - 10,000","5,000 - 10,000","15,000 - 40,000","0 - 5,000","15,000 - 40,000","5,000 - 10,000","0 - 5,000"]},{"axis":{"matches":true},"label":"HealthCare","values":["5,000 - 10,000","15,000 - 40,000","0 - 5,000","5,000 - 10,000","0 - 5,000","5,000 - 10,000","5,000 - 10,000","0 - 5,000","45,000 - 65,000","5,000 - 10,000","
# ...

# %% [markdown]
# Inference
#
# From the above plot, comparing indicators shows that the monthly cost of Electricity and Childcare is higher than the cost of Healthcare and Clothing across various Local Government areas of Lagos state. This means that earners spend a higer fraction of their Monthly income on Electricity. Also, the monthly cost of Childcare is higher compared to the monthly cost of Healthcare and Clothing.

# %%
plt.figure(figsize=(25,10))

plt.subplot(1,3,1)
sns.countplot(x='Accommodation' ,hue='Gender', data=cl_df,palette='coolwarm')

plt.subplot(1,3,2)
sns.countplot(x='Accommodation',hue='Marital_Status',data=cl_df,palette='bone')
plt.ylabel(' ')
plt.yticks([ ])

plt.subplot(1,3,3)
sns.countplot(x='Accommodation',hue='Age',data=cl_df,palette='PuRd')
plt.ylabel(' ')
plt.yticks([ ])
# Out:
# ([], [])

# %% [markdown]
# Inference
#
# From the graph above, the cost of Accommodation is more for Male than female, Single and married than widowed and divorced, and more from Age 31-35 than than the rest.

# %%
plt.figure(figsize=(25,10))

plt.subplot(1,3,1)
sns.countplot(x='Transportation' ,hue='Gender', data=cl_df,palette='viridis')

plt.subplot(1,3,2)
sns.countplot(x='Transportation',hue='Marital_Status',data=cl_df,palette='OrRd')
plt.ylabel(' ')
plt.yticks([ ])

plt.subplot(1,3,3)
sns.countplot(x='Transportation',hue='Age',data=cl_df,palette='twilight')
plt.ylabel(' ')
plt.yticks([ ])
# Out:
# ([], [])

# %% [markdown]
# Inference
#
# From the graph above, the cost of Transportation in Lagos is more for Male than female, Single and married than widowed and divorced, and more from Age 31-35 than than the rest.

# %%
plt.figure(figsize=(28,12))

plt.subplot(1,3,1)
sns.countplot(x='Feeding' ,hue='Gender', data=cl_df,palette='Accent')

plt.subplot(1,3,2)
sns.countplot(x='Feeding',hue='Marital_Status',data=cl_df,palette='hot_r')
plt.ylabel(' ')
plt.yticks([ ])

plt.subplot(1,3,3)
sns.countplot(x='Feeding',hue='Age',data=cl_df,palette='flare')
plt.ylabel(' ')
plt.yticks([ ])
# Out:
# ([], [])

# %% [markdown]
# Inference
#
# From the above graph, it shows that the cost of monthly Feeding in Lagos is more for Male than female, Single and married than widowed and divorced, and more from Age 31-35 than than the rest.

# %%
plt.figure(figsize=(28,12))

plt.subplot(1,3,1)
sns.countplot(x='Electricity' ,hue='Gender', data=cl_df,palette='Purples_r')

plt.subplot(1,3,2)
sns.countplot(x='Electricity',hue='Marital_Status',data=cl_df,palette='YlGn')
plt.ylabel(' ')
plt.yticks([ ])

plt.subplot(1,3,3)
sns.countplot(x='Electricity',hue='Age',data=cl_df,palette='RdBu_r')
plt.ylabel(' ')
plt.yticks([ ])
# Out:
# ([], [])

# %% [markdown]
# Inference
#
# From the above graph, it shows that the cost of monthly Electricity in Lagos is more for Male than female, Single and married than widowed and divoced, and more from Age 31-35 than than the rest.

# %%
plt.figure(figsize=(28,12))

plt.subplot(1,3,1)
sns.countplot(x='HealthCare' ,hue='Gender', data=cl_df,palette='hot_r')

plt.subplot(1,3,2)
sns.countplot(x='HealthCare',hue='Marital_Status',data=cl_df,palette='Purples_r')
plt.ylabel(' ')
plt.yticks([ ])

plt.subplot(1,3,3)
sns.countplot(x='HealthCare',hue='Age',data=cl_df,palette='YlGn')
plt.ylabel(' ')
plt.yticks([ ])
# Out:
# ([], [])

# %% [markdown]
# Inference
#
# From the above graph, it shows that the cost of monthly Healthcare in Lagos is more for Male than female, Single and married than widowed and divorced, and more from Age 31-35 than than the rest.

# %%
plt.figure(figsize=(25,10))

plt.subplot(1,3,1)
sns.countplot(x='Clothing' ,hue='Gender', data=cl_df,palette='plasma_r')

plt.subplot(1,3,2)
sns.countplot(x='Clothing',hue='Marital_Status',data=cl_df,palette='gist_gray_r')
plt.ylabel(' ')
plt.yticks([ ])

plt.subplot(1,3,3)
sns.countplot(x='Clothing',hue='Age',data=cl_df,palette='RdYlBu')
plt.ylabel(' ')
plt.yticks([ ])
# Out:
# ([], [])

# %% [markdown]
# Inference
#
# From the above graph, it shows that the cost of monthly Clothing in Lagos is more for Male than female, Single and married than widowed and divorced, and more from Age 31-35 than the rest.

# %%
plt.figure(figsize=(25,10))

plt.subplot(1,3,1)
sns.countplot(x='Childcare' ,hue='Gender', data=cl_df,palette='Greys')

plt.subplot(1,3,2)
sns.countplot(x='Childcare',hue='Marital_Status',data=cl_df,palette='gist_rainbow_r')
plt.ylabel(' ')
plt.yticks([ ])

plt.subplot(1,3,3)
sns.countplot(x='Childcare',hue='Age',data=cl_df,palette='afmhot_r')
plt.ylabel(' ')
plt.yticks([ ])
# Out:
# ([], [])

# %% [markdown]
# Inference
#
# From the above graph, it shows that the cost of monthly Healthcare in Lagos is more for Female than Male, widowed and married than single and more from Age 31-35 than than the rest.

# %%
plt.figure(figsize=(18,5))

plt.subplot(1,3,1)
sns.countplot(x='Health_Issues' ,hue='Gender', data=cl_df,palette='GnBu')

plt.subplot(1,3,2)
sns.countplot(x='Health_Issues',hue='Marital_Status',data=cl_df,palette='cool_r')
plt.ylabel(' ')
plt.yticks([ ])

plt.subplot(1,3,3)
sns.countplot(x='Health_Issues',hue='Age',data=cl_df,palette='hot_r')
plt.ylabel(' ')
plt.yticks([ ])
# Out:
# ([], [])

# %% [markdown]
# Inference
#
# From the above, we can see that, Female have more Health issues than the male category, the Married and Single than widowed, and Age 46-50 more than others.

# %% [markdown]
# ### Conclusion Phase
#
# The Analysis shows that, Out of 317 responses across 20 Local government area of Lagos state, 21.7% earn ₦20,000 - ₦50,000 per month, 23.7% earn ₦60,000 - ₦100,000 per month,  17.7% earn ₦100,000 - ₦150,000 per month,  13.2% earn ₦150,000 - ₦200,000 per month, 8.2% earn ₦200,000 - ₦290,000 per month,  6% earn more than ₦500,000 per month,  and 4.7% earn ₦300,000 - ₦500,000 per month.
#
# 35.3% spend ₦15,000 - ₦40,000 per month, 20.5% spend ₦95,000 above per month, 15.8% spend ₦5,000 - ₦10,000 per month, 12.3% spend ₦45,000 - ₦60,000 per month, 11% spend 0 - ₦5,000 per month 4.7% spend ₦65,000 - ₦90,000 per month and 0.3% spend ₦5,000 - ₦20,000 per month on monthly Accommodation
#
# 51.1% spend ₦15,000 - ₦40,000 per month, 23.3% spend ₦5,000 - ₦10,000 above per month, 10.1% spend ₦45,000 - ₦60,000 per month, 10.1% spend ₦0 - ₦5,000 per month, 5% spend ₦65,000 per month and 0.3% spend ₦5,000 - ₦20,000 per month on monthly Transportation.
#
# 36.3% spend ₦5,000 - ₦10,000 per month, 30.6% spend ₦0 - ₦5,000 per month,  25.2% spend ₦15,000 - ₦40,000 per month,  14.1% spend ₦45,000 - ₦60,000 per month, 1.6% spend ₦65,000 - ₦80,000 per month,  0.9% spend ₦85,000 - ₦100,000 per month 0.9% spend ₦100,000 above per month, and 0.3% spend ₦30,000 - ₦40,000 per month on monthly Electricity.
#
# 45.7% spend  ₦15,000 - ₦40,000 per month, 22.4%  spend ₦45,000 - ₦60,000 per month,  10.1% spend ₦65,000 - ₦80,000 per month,  6.9% spend ₦85,000 - ₦100,000 per month, 6.9% spend ₦100,000 above per month,  7.3% spend ₦5,000 - ₦10,000 per month on monthly Feeding.
#
# 41.6%  spend - ₦0 - ₦5,000 per month , 34.4% spend  ₦5,000 - ₦10,000 per month,  18% spend ₦15,000 - ₦40,000 per month,  4.1% spend ₦45,000 - ₦65,000 per month, 0.9% spend ₦90,000 above per month,  and 0.9% spend ₦70,000 - ₦85,000 per month on monthly Healthcare.
#
# 36.2% spend  ₦15,000 - ₦40,000 per month, 29.5%  spend ₦5,000 - ₦10,000 per month,  20.6% spend 0 - ₦5,000 per month,  7.9% spend ₦45,000 - ₦65,000 per month, 3.2% spend ₦70,000 - ₦95,000 per month,  2.5% spend ₦100,000 above per month on monthly Clothing.
#
# 48.3% spend  ₦0 - ₦5,000 per month, 21.3% spend ₦15,000 - ₦40,000 per month,  19.3% spend ₦5,000 - ₦10,000 per month, 6.4% spend ₦45,000 - ₦80,000 per month,  1.7% spend ₦85,000 - ₦100,000 per month and 3% spend ₦100,000 above per month on monthly Childcare.
#
#
# In conclusion, we can say the cost of living is high in Lagos, as the Analysis shows that, according to the response, people spend more than they actually earn. This can imply that people may have other source of income or may rely on other source for support. Also, among all indicators, they spend more of their monthly income on Feeding (food consumption) and Accommodation than Clothing, Transportation, Electricity, Healthcare and Childcare.
